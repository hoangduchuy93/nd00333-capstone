# %% [markdown]
# # Hyperparameter Tuning using HyperDrive
#
# TODO: Import Dependencies. In the cell below, import all the dependencies that you will need to complete the project.

# %%
# %pip install azureml-widgets
# %pip install azureml-train-automl-runtime==1.58.0
# %pip install --upgrade azureml-sdk[notebooks,automl]
# Out:
# Requirement already satisfied: azureml-widgets in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.58.0)
# Requirement already satisfied: azure-storage-blob>=12.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-widgets) (12.19.0)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-widgets) (7.8.4)
# Requirement already satisfied: jinja2<4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-widgets) (3.0.3)
# Requirement already satisfied: azureml-core~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-widgets) (1.58.0)
# Requirement already satisfied: azureml-telemetry~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-widgets) (1.58.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (1.31.0)
# Requirement already satisfied: cryptography>=2.1.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (43.0.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (0.6.1)
# Requirement already satisfied: pytz in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (2024.2)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.58.0->azureml-widgets) (2.32.3)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.31.0)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.2.0)
# Requirement already satisfied: knack<0.13.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.11.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.11.1)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (3.5.0)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (3.5.0)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (23.1.1)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (10.3.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (21.2.1)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (10.3.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=28.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (26.0.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.61.1)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.6.4.post1)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.26.20)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (24.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (2.9.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (3.3.3)
# Requirement already satisfied: jsonpickle<4.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (3.3.0)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (2.9.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (1.2.7)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (24.2.1)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-telemetry~=1.58.0->azureml-widgets) (0.11.10)
# Requirement already satisfied: comm>=0.1.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.9 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.6.9)
# Requirement already satisfied: ipython>=4.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jinja2<4.0->azureml-widgets) (2.1.5)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob>=12.6.0->azureml-widgets) (1.16.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.58.0->azureml-widgets) (1.4.0)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.6.0->azureml-widgets) (1.17.1)
# Requirement already satisfied: decorator in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.18.0)
# Requirement already satisfied: stack-data in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.9.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from knack<0.13.0->azureml-core~=1.58.0->azureml-widgets) (6.0.2)
# Requirement already satisfied: tabulate in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from knack<0.13.0->azureml-core~=1.58.0->azureml-widgets) (0.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from msal-extensions<=2.0.0,>=0.3.0->azureml-core~=1.58.0->azureml-widgets) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.58.0->azureml-widgets) (2024.8.30)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.58.0->azureml-widgets) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.58.0->azureml-widgets) (0.6.1)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.58.0->azureml-widgets) (4.2.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.58.0->azureml-widgets) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.58.0->azureml-widgets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.58.0->azureml-widgets) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.58.0->azureml-widgets) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from SecretStorage<4.0.0->azureml-core~=1.58.0->azureml-widgets) (0.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.5.7)
# Requirement already satisfied: backports.weakref in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from backports.tempfile->azureml-core~=1.58.0->azureml-widgets) (1.0.post1)
# Requirement already satisfied: pycparser in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.6.0->azureml-widgets) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.8.4)
# Requirement already satisfied: tornado>=6.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.4.1)
# Requirement already satisfied: pyzmq>=17 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (26.2.0)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.4.9)
# Requirement already satisfied: nbformat in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.10.3)
# Requirement already satisfied: nbconvert>=5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.6.0)
# Requirement already satisfied: ipykernel in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.29.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.13)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.58.0->azureml-widgets) (3.2.2)
# Requirement already satisfied: executing>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.4.1)
# Requirement already satisfied: pure-eval in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.3)
# Requirement already satisfied: entrypoints in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-client<8,>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.1.0)
# Requirement already satisfied: defusedxml in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.5.0)
# Requirement already satisfied: tinycss2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: fastjsonschema in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.5)
# Requirement already satisfied: psutil in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.9.3)
# Requirement already satisfied: webencodings in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.20.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.14.2)
# Requirement already satisfied: soupsieve>1.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.5)
# Requirement already satisfied: anyio>=3.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.7.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.1)
# Requirement already satisfied: fqdn in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.5.1)
# Requirement already satisfied: isoduration in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.0)
# Requirement already satisfied: uri-template in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (24.8.0)
# Requirement already satisfied: arrow>=0.15.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.9.0.20240906)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azureml-train-automl-runtime==1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.58.0)
# Requirement already satisfied: azure-storage-queue~=12.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (12.12.0)
# Requirement already satisfied: lightgbm<=3.2.1,>=3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (3.2.1)
# Requirement already satisfied: pandas==1.5.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.5.3)
# Requirement already satisfied: scipy<=1.11.0,>=1.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.10.1)
# Requirement already satisfied: scikit-learn~=1.5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.5.1)
# Requirement already satisfied: sklearn-pandas<=1.7.0,>=1.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.7.0)
# Requirement already satisfied: statsmodels<0.14,>=0.13.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (0.13.5)
# Requirement already satisfied: skl2onnx==1.15.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.15.0)
# Requirement already satisfied: onnxmltools==1.11.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.11.2)
# Requirement already satisfied: keras2onnx<=1.6.0,>=1.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.6.0)
# Requirement already satisfied: onnxconverter-common==1.13.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.13.0)
# Requirement already satisfied: onnx==1.16.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.16.1)
# Requirement already satisfied: onnxruntime~=1.17.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.17.3)
# Requirement already satisfied: jinja2<4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (3.0.3)
# Requirement already satisfied: boto3<=1.20.19 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.20.19)
# Requirement already satisfied: botocore<=1.23.19 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.23.19)
# Requirement already satisfied: urllib3<2.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.26.20)
# Requirement already satisfied: dask<=2023.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (2023.2.0)
# Requirement already satisfied: bokeh<3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (2.4.3)
# Requirement already satisfied: pyyaml<7.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (6.0.2)
# Requirement already satisfied: pyarrow==14.0.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (14.0.2)
# Requirement already satisfied: azureml-automl-core~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-automl-runtime~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-train-automl-client~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-core~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-telemetry~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-interpret~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-dataset-runtime~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: azureml-mlflow~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: numpy<=1.23.5,>=1.16.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (1.23.5)
# Requirement already satisfied: gensim==4.3.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (4.3.2)
# Requirement already satisfied: smart-open==6.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-runtime==1.58.0) (6.4.0)
# Requirement already satisfied: protobuf>=3.20.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from onnx==1.16.1->azureml-train-automl-runtime==1.58.0) (3.20.3)
# Requirement already satisfied: packaging in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from onnxconverter-common==1.13.0->azureml-train-automl-runtime==1.58.0) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pandas==1.5.3->azureml-train-automl-runtime==1.58.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pandas==1.5.3->azureml-train-automl-runtime==1.58.0) (2024.2)
# Requirement already satisfied: azure-core>=1.30.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime==1.58.0) (1.31.0)
# Requirement already satisfied: cryptography>=2.1.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime==1.58.0) (43.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime==1.58.0) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime==1.58.0) (0.6.1)
# Requirement already satisfied: importlib-metadata<=8.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (8.2.0)
# Requirement already satisfied: importlib-resources<=6.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (6.4.0)
# Requirement already satisfied: azureml-training-tabular~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: dill<0.4.0,>=0.2.8 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.3.9)
# Requirement already satisfied: psutil<5.9.4,>=5.2.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (5.9.3)
# Requirement already satisfied: pmdarima==1.8.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.8.5)
# Requirement already satisfied: joblib==1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.2.0)
# Requirement already satisfied: dataclasses<=0.8,>=0.6 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.6)
# Requirement already satisfied: arch<=5.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (5.6.0)
# Requirement already satisfied: dotnetcore2<4.0.0,>=3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.1.23)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pmdarima==1.8.5->azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.0.11)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pmdarima==1.8.5->azureml-automl-runtime~=1.58.0->azureml-train-automl-runtime==1.58.0) (75.1.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (2.32.3)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.31.0)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.2.0)
# Requirement already satisfied: knack<0.13.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.11.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.11.1)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.5.0)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.5.0)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (23.1.1)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (10.3.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (21.2.1)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (10.3.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=28.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (26.0.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.61.1)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.6.4.post1)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.3.3)
# Requirement already satisfied: jsonpickle<4.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.3.0)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (2.9.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.2.7)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (24.2.1)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-core~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.10.0)
# Requirement already satisfied: azureml-dataprep<5.2.0a,>=5.1.0a in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-dataset-runtime~=1.58.0->azureml-dataset-runtime[fuse,pandas]~=1.58.0->azureml-train-automl-runtime==1.58.0) (5.1.6)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.58.0->azureml-train-automl-runtime==1.58.0) (3.0.1)
# Requirement already satisfied: interpret-community==0.31.* in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-interpret~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.31.0)
# Requirement already satisfied: numba<=0.56.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-interpret~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.56.4)
# Requirement already satisfied: ml-wrappers~=0.5.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from interpret-community==0.31.*->azureml-interpret~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.5.6)
# Requirement already satisfied: shap<=0.44.0,>=0.20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from interpret-community==0.31.*->azureml-interpret~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.43.0)
# Requirement already satisfied: raiutils~=0.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from interpret-community==0.31.*->azureml-interpret~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.4.2)
# Requirement already satisfied: interpret-core<=0.5.0,>=0.1.20 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from interpret-community==0.31.*->azureml-interpret~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.5.0)
# Requirement already satisfied: mlflow-skinny in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-mlflow~=1.58.0->azureml-train-automl-runtime==1.58.0) (2.17.1)
# Requirement already satisfied: azure-identity in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-mlflow~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.19.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-mlflow~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.4.0)
# Requirement already satisfied: azure-storage-blob<=12.19.0,>=12.5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-mlflow~=1.58.0->azureml-train-automl-runtime==1.58.0) (12.19.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-telemetry~=1.58.0->azureml-train-automl-runtime==1.58.0) (0.11.10)
# Requirement already satisfied: azureml-train-core~=1.58.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from azureml-train-automl-client~=1.58.0->azureml-train-automl-runtime==1.58.0) (1.58.0)
# Requirement already satisfied: pillow>=7.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from bokeh<3.0.0->azureml-train-automl-runtime==1.58.0) (10.4.0)
# Requirement already satisfied: tornado>=5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from bokeh<3.0.0->azureml-train-automl-runtime==1.58.0) (6.4.1)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from boto3<=1.20.19->azureml-train-automl-runtime==1.58.0) (0.5.2)
# Requirement already satisfied: click>=7.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (2024.9.0)
# Requirement already satisfied: partd>=0.3.10 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask<=2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (1.0.0)
# Requirement already satisfied: distributed==2023.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (2023.2.0)
# Requirement already satisfied: locket>=1.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (1.1.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (3.0.0)
# Requirement already satisfied: zict>=2.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from distributed==2023.2.0->dask[complete]<=2023.2.0->azureml-train-automl-runtime==1.58.0) (3.0.0)
# ...
# Requirement already satisfied: flatbuffers in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from onnxruntime~=1.17.3->azureml-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (24.3.25)
# Requirement already satisfied: sympy in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from onnxruntime~=1.17.3->azureml-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (1.13.3)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pexpect>4.3->ipython->azureml-contrib-notebook~=1.58.0->azureml-sdk[automl,notebooks]) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->azureml-contrib-notebook~=1.58.0->azureml-sdk[automl,notebooks]) (0.2.13)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.58.0->azureml-sdk[automl,notebooks]) (3.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from scikit-learn~=1.5.1->azureml-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (3.5.0)
# Requirement already satisfied: patsy>=0.5.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from statsmodels<0.14,>=0.13.0->azureml-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.5.6)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from beautifulsoup4->nbconvert<8->azureml-contrib-notebook~=1.58.0->azureml-sdk[automl,notebooks]) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from stack-data->ipython->azureml-contrib-notebook~=1.58.0->azureml-sdk[automl,notebooks]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from stack-data->ipython->azureml-contrib-notebook~=1.58.0->azureml-sdk[automl,notebooks]) (2.4.1)
# Requirement already satisfied: pure-eval in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from stack-data->ipython->azureml-contrib-notebook~=1.58.0->azureml-sdk[automl,notebooks]) (0.2.3)
# Requirement already satisfied: pycparser in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.58.0->azureml-sdk[automl,notebooks]) (2.22)
# Requirement already satisfied: sparse in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from econml>=0.14.1->responsibleai==0.36.0->azureml-responsibleai~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.15.4)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (23.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.18.1)
# Requirement already satisfied: prometheus-client in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from numba<=0.58.1->responsibleai==0.36.0->azureml-responsibleai~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.39.1)
# Requirement already satisfied: termcolor in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from fire->keras2onnx<=1.6.0,>=1.4.0->azureml-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (2.5.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (5.5.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.36.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (3.1.43)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (1.27.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from sympy->onnxruntime~=1.17.3->azureml-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (1.3.0)
# Requirement already satisfied: google-auth~=2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (2.35.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (4.0.11)
# Requirement already satisfied: notebook-shim>=0.2.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.2.4)
# Requirement already satisfied: deprecated>=1.2.6 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.48b0)
# Requirement already satisfied: slicer==0.0.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from shap<=0.44.0,>=0.20.0->interpret-community>=0.31.0->responsibleai==0.36.0->azureml-responsibleai~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.0.7)
# Requirement already satisfied: argon2-cffi-bindings in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (21.2.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny->azureml-mlflow~=1.58.0->azureml-train-automl-runtime~=1.58.0->azureml-train-automl~=1.58.0->azureml-sdk[automl,notebooks]) (4.9)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (2.14.2)
# Requirement already satisfied: anyio>=3.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (3.7.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (0.1.1)
# Requirement already satisfied: fqdn in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.5.1)
# Requirement already satisfied: isoduration in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (3.0.0)
# Requirement already satisfied: uri-template in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (24.8.0)
# Requirement already satisfied: arrow>=0.15.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.9->ipywidgets<8.0.0,>=7.0.0->azureml-widgets~=1.58.0->azureml-sdk[automl,notebooks]) (2.9.0.20240906)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Dataset
#
# TODO: Get data. In the cell below, write code to access the data you will be using in this project. Remember that the dataset needs to be external.

# %%
from azureml.core import Workspace, Experiment

# %%
ws = Workspace.from_config(path="Users/odl_user_269141/config.json")
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')

experiment_name = 'hyperparameter-tunning'

experiment=Experiment(ws, experiment_name)
# Out:
# quick-starts-ws-269141
# aml-quickstarts-269141
# westus2
# 61c5c3f0-6dc7-4ed9-a7f3-c704b20e3b30

# %%
from azureml.widgets import RunDetails
from azureml.train.sklearn import SKLearn
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.policy import BanditPolicy
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.runconfig import HyperDriveConfig
from azureml.train.hyperdrive.parameter_expressions import choice, uniform
from azureml.core import Environment, ScriptRunConfig
import os

# %% [markdown]
# Compute Cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "my-compute-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D3_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# Dataset review

# %%
import logging
import os
import csv

import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.58.0

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "survival-possibility-titanic"
description_text = "Possibility of a passenger can survive"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://raw.githubusercontent.com/hoangduchuy93/nd00333-capstone/refs/heads/main/train_survival.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.head()
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}
#    PassengerId  Survived  Pclass  \
# 0            1     False       3
# 1            2      True       1
# 2            3      True       3
# 3            4      True       1
# 4            5     False       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %% [markdown]
# ## Hyperdrive Configuration
#
# TODO: Explain the model you are using and the reason for chosing the different hyperparameters, termination policy and config settings.

# %%
# TODO: Create an early termination policy. This is not required if you are using Bayesian sampling.
early_termination_policy = BanditPolicy(slack_factor=0.2, evaluation_interval=1)


#TODO: Create the different params that you will be using during training
param_sampling = RandomParameterSampling(
    {"C": uniform(0.05, 0.1),
    "max_iter" : choice(16, 32, 64, 128)}
)

if "training" not in os.listdir():
    os.mkdir("./training")

# Setup environment for your training run
sklearn_env = Environment.from_conda_specification(name='sklearn-env', 
file_path='conda_dependencies.yml')

# Create a ScriptRunConfig Object to specify the configuration details of your training job
src = ScriptRunConfig(
    source_directory=".",
    script="train.py",
    environment=sklearn_env,
    compute_target=compute_target
)

# Create a HyperDriveConfig using the src object, hyperparameter sampler, and policy.
hyperdrive_run_config = HyperDriveConfig(
    run_config=src,
    hyperparameter_sampling=param_sampling,
    policy=early_termination_policy,
    primary_metric_name="Accuracy",
    primary_metric_goal=PrimaryMetricGoal.MAXIMIZE,
    max_total_runs=10,
    max_concurrent_runs=4
)

# %%
#TODO: Submit your experiment
experiment_run = experiment.submit(hyperdrive_run_config)

# %% [markdown]
# ## Run Details
#
# OPTIONAL: Write about the different models trained and their performance. Why do you think some models did better than others?
#
# TODO: In the cell below, use the `RunDetails` widget to show the different experiments.

# %%
RunDetails(experiment_run).show()
experiment_run.wait_for_completion(show_output=True)
# Out:
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…
# RunId: HD_705bf859-07b5-4591-ae69-eb8ba4b4f556
# Web View: https://ml.azure.com/runs/HD_705bf859-07b5-4591-ae69-eb8ba4b4f556?wsid=/subscriptions/61c5c3f0-6dc7-4ed9-a7f3-c704b20e3b30/resourcegroups/aml-quickstarts-269141/workspaces/quick-starts-ws-269141&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
#
# Streaming azureml-logs/hyperdrive.txt
# =====================================
#
# [2024-10-27T02:29:40.184221][GENERATOR][INFO]Trying to sample '4' jobs from the hyperparameter space
# [2024-10-27T02:29:40.6224825Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_0'
# [2024-10-27T02:29:40.7576790Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_1'
# [2024-10-27T02:29:40.8663668Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_2'
# [2024-10-27T02:29:40.942033][GENERATOR][INFO]Successfully sampled '4' jobs, they will soon be submitted to the execution target.
# [2024-10-27T02:29:40.9903295Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_3'
# [2024-10-27T02:29:41.3518446Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_1'
# [2024-10-27T02:29:41.2954288Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_2'
# [2024-10-27T02:29:41.3153106Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_3'
# [2024-10-27T02:29:41.3614169Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_0'
# [2024-10-27T02:45:40.148693][GENERATOR][INFO]Trying to sample '2' jobs from the hyperparameter space
# [2024-10-27T02:45:40.5763502Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_5'
# [2024-10-27T02:45:40.4461047Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_4'
# [2024-10-27T02:45:40.505980][GENERATOR][INFO]Successfully sampled '2' jobs, they will soon be submitted to the execution target.
# [2024-10-27T02:45:41.0079081Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_4'
# [2024-10-27T02:45:41.1987391Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_5'
# [2024-10-27T02:46:40.184150][GENERATOR][INFO]Trying to sample '2' jobs from the hyperparameter space
# [2024-10-27T02:46:40.5168298Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_6'
# [2024-10-27T02:46:40.6193491Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_7'
# [2024-10-27T02:46:40.573032][GENERATOR][INFO]Successfully sampled '2' jobs, they will soon be submitted to the execution target.
# [2024-10-27T02:46:40.8444747Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_6'
# [2024-10-27T02:46:40.9097140Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_7'
# [2024-10-27T02:47:10.111735][GENERATOR][INFO]Trying to sample '2' jobs from the hyperparameter space
# [2024-10-27T02:47:10.5277082Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_8'
# [2024-10-27T02:47:10.7425562Z][SCHEDULER][INFO]Scheduling job, id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_9'
# [2024-10-27T02:47:10.8305129Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_8'
# [2024-10-27T02:47:10.559490][GENERATOR][INFO]Successfully sampled '2' jobs, they will soon be submitted to the execution target.
# [2024-10-27T02:47:11.0550482Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_9'
# [2024-10-27T02:47:40.288659][GENERATOR][INFO]Max number of jobs '10' reached for experiment.
# [2024-10-27T02:47:40.496140][GENERATOR][INFO]All jobs generated.
# [2024-10-27T02:48:48.2015317Z][CONTROLLER][INFO]Changing Run Status from Running to Completed
#
# Execution Summary
# =================
# RunId: HD_705bf859-07b5-4591-ae69-eb8ba4b4f556
# Web View: https://ml.azure.com/runs/HD_705bf859-07b5-4591-ae69-eb8ba4b4f556?wsid=/subscriptions/61c5c3f0-6dc7-4ed9-a7f3-c704b20e3b30/resourcegroups/aml-quickstarts-269141/workspaces/quick-starts-ws-269141&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# {'runId': 'HD_705bf859-07b5-4591-ae69-eb8ba4b4f556',
#  'target': 'my-compute-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2024-10-27T02:29:39.443192Z',
#  'endTimeUtc': '2024-10-27T02:48:48.282969Z',
#  'services': {},
#  'properties': {'primary_metric_config': '{"name":"Accuracy","goal":"maximize"}',
#   'resume_from': 'null',
#   'runTemplate': 'HyperDrive',
#   'azureml.runsource': 'hyperdrive',
#   'platform': 'AML',
#   'ContentSnapshotId': '3b5467f5-c582-4998-8bb6-725a607d43fe',
#   'user_agent': 'python/3.10.11 (Linux-5.15.0-1073-azure-x86_64-with-glibc2.31) msrest/0.7.1 Hyperdrive.Service/1.0.0 Hyperdrive.SDK/core.1.58.0',
#   'space_size': 'infinite_space_size',
#   'best_child_run_id': 'HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_5',
#   'score': '0.7297297297297297',
#   'best_metric_status': 'Succeeded',
#   'best_data_container_id': 'dcid.HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_5'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'configuration': None,
#   'attribution': None,
#   'telemetryValues': {'amlClientType': 'azureml-sdk-train',
#    'amlClientModule': '[Scrubbed]',
#    'amlClientFunction': '[Scrubbed]',
#    'tenantId': '660b3398-b80e-49d2-bc5b-ac1dc93b5254',
#    'amlClientRequestId': '9ca7662b-b6ab-47ed-b4ec-6cb518d8b35e',
#    'amlClientSessionId': '6a66979b-5979-48b2-9017-9339001a3466',
#    'subscriptionId': '61c5c3f0-6dc7-4ed9-a7f3-c704b20e3b30',
#    'estimator': 'NoneType',
#    'samplingMethod': 'RANDOM',
#    'terminationPolicy': 'Bandit',
#    'primaryMetricGoal': 'maximize',
#    'maxTotalRuns': 10,
#    'maxConcurrentRuns': 4,
#    'maxDurationMinutes': 10080,
#    'vmSize': None},
#   'snapshotId': '3b5467f5-c582-4998-8bb6-725a607d43fe',
#   'snapshots': [],
#   'sourceCodeDataReference': None,
#   'parentRunId': None,
#   'dataContainerId': None,
#   'runType': None,
#   'displayName': None,
#   'environmentAssetId': None,
#   'properties': {},
#   'tags': {},
#   'aggregatedArtifactPath': None},
#  'logFiles': {'azureml-logs/hyperdrive.txt': 'https://mlstrg269141.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_705bf859-07b5-4591-ae69-eb8ba4b4f556/azureml-logs/hyperdrive.txt?sv=2019-07-07&sr=b&sig=2EEocA5d2%2FZtRPmx3NSYaDxAD%2FJtNE2BJWcZLDORgwA%3D&skoid=9d2474d7-d807-4e4f-93ee-0dd63dd4f46f&sktid=660b3398-b80e-49d2-bc5b-ac1dc93b5254&skt=2024-10-27T00%3A52%3A48Z&ske=2024-10-29T01%3A02%3A48Z&sks=b&skv=2019-07-07&st=2024-10-27T02%3A39%3A24Z&se=2024-10-27T10%3A49%3A24Z&sp=r'},
#  'submittedBy': 'ODL_User 269141'}

# %% [markdown]
# ## Best Model
#
# TODO: In the cell below, get the best model from the hyperdrive experiments and display all the properties of the model.

# %%
import joblib
# Get your best run and save the model from that run.

best_run = experiment_run.get_best_run_by_primary_metric()
print(best_run.get_metrics())
# Out:
# {'Regularization Strength:': 0.07454767022806216, 'Max iterations:': 64, 'Accuracy': 0.7297297297297297}

# %%
best_run
# Out:
# Run(Experiment: hyperparameter-tunning,
# Id: HD_705bf859-07b5-4591-ae69-eb8ba4b4f556_5,
# Type: azureml.scriptrun,
# Status: Completed)

# %%
best_run.get_file_names()
# Out:
# ['logs/azureml/dataprep/0/backgroundProcess.log',
#  'logs/azureml/dataprep/0/backgroundProcess_Telemetry.log',
#  'logs/azureml/dataprep/0/rslex.log.2024-10-27-02',
#  'outputs/model.joblib',
#  'system_logs/cs_capability/cs-capability.log',
#  'system_logs/hosttools_capability/hosttools-capability.log',
#  'system_logs/lifecycler/execution-wrapper.log',
#  'system_logs/lifecycler/lifecycler.log',
#  'system_logs/metrics_capability/metrics-capability.log',
#  'system_logs/snapshot_capability/snapshot-capability.log',
#  'user_logs/std_log.txt']

# %%
#TODO: Save the best model
#Save model
best_run.register_model(model_name = "auto_hyper_best_model",
model_path="outputs/model.joblib")
# Out:
# Model(workspace=Workspace.create(name='quick-starts-ws-269141', subscription_id='61c5c3f0-6dc7-4ed9-a7f3-c704b20e3b30', resource_group='aml-quickstarts-269141'), name=auto_hyper_best_model, id=auto_hyper_best_model:1, version=1, tags={}, properties={})

# %% [markdown]
# ## Model Deployment
#
# Remember you have to deploy only one of the two models you trained but you still need to register both the models. Perform the steps in the rest of this notebook only if you wish to deploy this model.
#
# TODO: In the cell below, register the model, create an inference config and deploy the model as a web service.

# %% [markdown]
# TODO: In the cell below, send a request to the web service you deployed to test it.

# %% [markdown]
# TODO: In the cell below, print the logs of the web service and delete the service

# %% [markdown]
# **Submission Checklist**
# - I have registered the model.
# - I have deployed the model with the best accuracy as a webservice.
# - I have tested the webservice by sending a request to the model endpoint.
# - I have deleted the webservice and shutdown all the computes that I have used.
# - I have taken a screenshot showing the model endpoint as active.
# - The project includes a file containing the environment details.
